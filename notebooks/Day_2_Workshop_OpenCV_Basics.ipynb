# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image=cv2.imread("Tom.jpg")

# %%
cv2.imshow('Tom.jpg',image)
small = cv2.resize(image, (400, 300))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(image)
plt.title("BGR")
plt.axis('off')
plt.show()

# %%
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
plt.title("Original")
plt.axis('off')
plt.show()

# %%
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2GRAY))
plt.title("Original")
plt.axis('off')
plt.show()

# %% [raw]
# gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
# cv2.imshow("Image",gray)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
plt.imshow(image,cmap='gray')
plt.title("RGB Image")
plt.axis('off')
plt.show()

# %%
resized_img=cv2.resize(image,(400,400))
cv2.imshow("Image",resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(resized_img,cv2.COLOR_BGR2RGB))
plt.title("Original")
plt.show()

# %%
scaled_img=cv2.resize(image,None,fx=0.2,fy=0.2)
cv2.imshow("Image",scaled_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
resized_rgb=cv2.cvtColor(resized_img,cv2.COLOR_BGR2RGB)
scaled_rgb=cv2.cvtColor(scaled_img,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,5))
plt.subplot(1,3,1)
plt.imshow(img_rgb)
plt.title("Original")

plt.subplot(1,3,2)
plt.imshow(resized_rgb)
plt.title("Fixed Resize")

plt.subplot(1,3,3)
plt.imshow(scaled_rgb)
plt.title("scaled Resize")
# Out:
# Text(0.5, 1.0, 'scaled Resize')

# %% [markdown]
# # flip

# %%
image=cv2.imread('Tom.jpg')
horizontal=cv2.flip(image,1)
vertical=cv2.flip(image,0)
both=cv2.flip(image,-1)

plt.figure(figsize=(20,5))

plt.subplot(1,4,1)
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
plt.title("Original")

plt.subplot(1,4,2)
plt.imshow(cv2.cvtColor(horizontal,cv2.COLOR_BGR2RGB))
plt.title("Horizontal")

plt.subplot(1,4,3)
plt.imshow(cv2.cvtColor(vertical,cv2.COLOR_BGR2RGB))
plt.title("Vertical")

plt.subplot(1,4,4)
plt.imshow(cv2.cvtColor(both,cv2.COLOR_BGR2RGB))
plt.title("Both")

plt.show()

# %%
img=cv2.imread('Tom.jpg')

print("Image Shape:",img.shape)
h,w=img.shape[:2]
row_start=int(h*0.2)
row_end=int(h*0.6)
col_start=int(w*0.2)
col_end=int(w*0.6)

cropped=img[row_start:row_end,col_start:col_end]


plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
plt.title("Original")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(cropped,cv2.COLOR_BGR2RGB))
plt.title("Cropped")



plt.show()
# Out:
# Image Shape: (1003, 564, 3)

# %%
img=cv2.imread('Tom.jpg')

rows,cols=img.shape[:2]

M=np.float32([[1,0,50],[0,1,100]])
#1:for scaling
#0:for slanting
#50:third column:for shifting
translated=cv2.warpAffine(image,M,(cols,rows))
plt.imshow(cv2.cvtColor(translated,cv2.COLOR_BGR2RGB))
plt.title("Translated Image")
plt.show()

# %%
img=cv2.imread('Tom.jpg')

rows,cols=img.shape[:2]

M=np.float32([[1,0,5],[0,1,10]])
#1:for scaling
#0:for slanting
#50:third column:for shifting
translated=cv2.warpAffine(image,M,(cols,rows))
plt.imshow(cv2.cvtColor(translated,cv2.COLOR_BGR2RGB))
plt.title("Translated Image")
plt.show()

# %%
img=cv2.imread('Tom.jpg')

rows,cols=img.shape[:2]

M=np.float32([[1,0,-50],[0,1,-100]])
#1:for scaling
#0:for slanting
#50:third column:for shifting
translated=cv2.warpAffine(image,M,(cols,rows))
plt.imshow(cv2.cvtColor(translated,cv2.COLOR_BGR2RGB))
plt.title("Translated Image")
plt.show()

# %%
img=cv2.imread('Tom.jpg')

rows,cols=img.shape[:2]

M=np.float32([[10,0,-50],[0,10,-100]])
#1:for scaling
#0:for slanting
#50:third column:for shifting
translated=cv2.warpAffine(image,M,(cols,rows))
plt.imshow(cv2.cvtColor(translated,cv2.COLOR_BGR2RGB))
plt.title("Translated Image")
plt.show()

# %%
center=(cols//2,rows//2)
M=cv2.getRotationMatrix2D(center,45,1)
rotated=cv2.warpAffine(image,M,(cols,rows))
plt.imshow(cv2.cvtColor(rotated,cv2.COLOR_BGR2RGB))
plt.title("rotated Image")
plt.show()

# %%
center=(cols//2,rows//2)
M=cv2.getRotationMatrix2D(center,37,1)
rotated=cv2.warpAffine(image,M,(cols,rows))
plt.imshow(cv2.cvtColor(rotated,cv2.COLOR_BGR2RGB))
plt.title("rotated Image")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt


image=cv2.imread('Tom.jpg')
cv2.rectangle(image,(50, 50), (300, 200),(0, 255, 0),3)
cv2.circle(image,(500, 150),80,(255, 0, 0),  3)
cv2.putText(image,"My Tom",(300, 300),cv2.FONT_HERSHEY_SIMPLEX,1,(0, 0, 255),2,cv2.LINE_AA                  )


plt.figure(figsize=(10,6))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Rectangle + Circle + Text")
plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

black = np.zeros((300,300), dtype=np.uint8)
dark = np.ones((300,300), dtype=np.uint8)
white = np.full((300,300), 255, dtype=np.uint8)
gray = np.full((300,300), 127, dtype=np.uint8)

plt.figure(figsize=(20,5))

plt.subplot(1,4,1)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
plt.title("Gray")

plt.subplot(1,4,2)
plt.imshow(cv2.cvtColor(black, cv2.COLOR_BGR2RGB))
plt.title("Black")

plt.subplot(1,4,3)
plt.imshow(cv2.cvtColor(dark, cv2.COLOR_BGR2RGB))
plt.title("Dark-Almost Black")

plt.subplot(1,4,4)
plt.imshow(cv2.cvtColor(white, cv2.COLOR_BGR2RGB))
plt.title("White")

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

 
img1 = np.zeros((300, 300), dtype=np.uint8)
img2 = np.zeros((300, 300), dtype=np.uint8)



cv2.rectangle(img1, (50, 50), (200, 200), 255, -1)


cv2.circle(img2, (150, 150), 100, 255, -1)

bit_and = cv2.bitwise_and(img1, img2)
bit_or = cv2.bitwise_or(img1, img2)
bit_xor = cv2.bitwise_xor(img1, img2)
bit_not = cv2.bitwise_not(img2)

titles = ["Image 1", "Image 2", "AND", "OR", "XOR", "NOT"]

images = [img1, img2, bit_and, bit_or, bit_xor, bit_not]

for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = np.full((500, 500, 3), 255, dtype=np.uint8)

cv2.rectangle(img, (70, 70), (220, 220), (255, 0, 0), 3)


cv2.circle(img, (350, 150), 70, (0, 255, 0), -1)


cv2.putText(img,
            "Akshata",
            (130, 420),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 0, 255),
            2,
            cv2.LINE_AA)


plt.figure(figsize=(6,6))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("My Image Design")
plt.axis("off")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = np.full((600, 400, 3), 255, dtype=np.uint8)


cv2.rectangle(img, (120, 50), (280, 400), (0, 0, 0), 3)


cv2.circle(img, (200, 120), 45, (0, 0, 255), -1)


cv2.circle(img, (200, 225), 45, (0, 255, 255), -1)


cv2.circle(img, (200, 330), 45, (0, 255, 0), -1)


cv2.putText(img,
            "Traffic Signal",
            (80, 500),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (255, 0, 0),
            2,
            cv2.LINE_AA)


plt.figure(figsize=(5,7))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Traffic Signal")
plt.axis("off")
plt.show()
